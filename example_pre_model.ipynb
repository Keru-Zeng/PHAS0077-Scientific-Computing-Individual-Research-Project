# %%
#import library
from premodel_functions import *

# %%
# To test the results of premodel functions
nuclei, nps, nrows, ncols = stackloader(
    "1.2%_1Hour_EEA-1.lif - Series001.tif",
    dir_in="tifs_unanalysed/1.2%_1Hour_EEA-1/tifs/",
    plot=True,
)

# %%
plotpic(
    "1.2%_1Hour_EEA-1.lif - Series001.tif",
    dir_in="tifs_unanalysed/1.2%_1Hour_EEA-1/tifs/",
    plot=True,
)

# %%
filefolder(dirname="tifs_unanalysed/", plot=True)
